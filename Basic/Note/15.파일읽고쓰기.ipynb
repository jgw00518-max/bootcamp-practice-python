# %% [markdown]
# #### 파일 읽고 쓰기

# %%
# 파일을 쓰기모드로 열어 출력값 저장하기.

f = open("../Data/new.txt", 'w')

for i in range(1, 10+1):
    data = f"{i}번째 줄 입니다.\n"
    f.write(data)
    
f.close()

# %%
# 파일을 읽기모드로 열어 파일 내용 출력하기
f = open("../Data/new.txt", 'r')

while True:
    line = f.readline()
    if not line:
        break
    print(line, end="")

f.close()
# Out:
# 1번째 줄 입니다.
# 2번째 줄 입니다.
# 3번째 줄 입니다.
# 4번째 줄 입니다.
# 5번째 줄 입니다.
# 6번째 줄 입니다.
# 7번째 줄 입니다.
# 8번째 줄 입니다.
# 9번째 줄 입니다.
# 10번째 줄 입니다.

# %%
# 파일을 읽기모드로 열어 파일 내용 출력하기 - 2
f = open("../Data/new.txt", 'r')
lines = f.readlines()
for line in lines:
    print(line, end="")

f.close()
# Out:
# 1번째 줄 입니다.
# 2번째 줄 입니다.
# 3번째 줄 입니다.
# 4번째 줄 입니다.
# 5번째 줄 입니다.
# 6번째 줄 입니다.
# 7번째 줄 입니다.
# 8번째 줄 입니다.
# 9번째 줄 입니다.
# 10번째 줄 입니다.

# %%
# 파일을 읽기모드로 열어 파일 내용 출력하기 - 3
f = open("../Data/new.txt", 'r')
data = f.read()
print(data)
f.close()
# Out:
# 1번째 줄 입니다.
# 2번째 줄 입니다.
# 3번째 줄 입니다.
# 4번째 줄 입니다.
# 5번째 줄 입니다.
# 6번째 줄 입니다.
# 7번째 줄 입니다.
# 8번째 줄 입니다.
# 9번째 줄 입니다.
# 10번째 줄 입니다.

# %%
# 파일에 새로운 내용 추가하기
f = open("../Data/new.txt", 'a')

for i in range(11, 20+1):
    data = f"{i}번째 줄 입니다.\n"
    f.write(data)

f.close()

# %% [markdown]
# ---
# #### with문
# : 파일의 열고 닫음을 자동으로 처리하기 위해 사용하며 with문을 벗어나면 자동으로 close()

# %%
# 파일 만들기
with open("../Data/new2.txt", "w") as f:
    for i in range(1, 10+1):
        data = f"{i}번째 줄 입니다.\n"
        f.write(data)

# %%
# 파일 읽기
with open("../Data/new2.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# 1번째 줄 입니다.
# 2번째 줄 입니다.
# 3번째 줄 입니다.
# 4번째 줄 입니다.
# 5번째 줄 입니다.
# 6번째 줄 입니다.
# 7번째 줄 입니다.
# 8번째 줄 입니다.
# 9번째 줄 입니다.
# 10번째 줄 입니다.

# %% [markdown]
# ----
# #### Pandas로 불러오기

# %%
import pandas as pd

# %%
a = pd.read_table("../Data/new.txt", header=None)
a.columns = ['line']
a
# Out:
#            line
# 0    1번째 줄 입니다.
# 1    2번째 줄 입니다.
# 2    3번째 줄 입니다.
# 3    4번째 줄 입니다.
# 4    5번째 줄 입니다.
# 5    6번째 줄 입니다.
# 6    7번째 줄 입니다.
# 7    8번째 줄 입니다.
# 8    9번째 줄 입니다.
# 9   10번째 줄 입니다.
# 10  11번째 줄 입니다.
# 11  12번째 줄 입니다.
# 12  13번째 줄 입니다.
# 13  14번째 줄 입니다.
# 14  15번째 줄 입니다.
# 15  16번째 줄 입니다.
# 16  17번째 줄 입니다.
# 17  18번째 줄 입니다.
# 18  19번째 줄 입니다.
# 19  20번째 줄 입니다.
