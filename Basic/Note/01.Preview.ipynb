# %% [markdown]
# # Python 기초
#
# ### 사칙연산

# %%
# 덧셈
1 + 2
# Out:
# 3

# %%
# 곱셈
2 * 3
# Out:
# 6

# %%
# 뺄셈
5 - 2
# Out:
# 3

# %%
# 실수 나눗셈
3 / 2
# Out:
# 1.5

# %%
# 정수 나눗셈의 나머지
5 % 2
# Out:
# 1

# %%
# 정수 나눗셈의 몫
5 // 2
# Out:
# 2

# %% [markdown]
# ---
# # 변수에 대입하여 계산하기

# %%
# 변수에 정수를 할당하여 계산하기
var_1 = 2
var_2 = 5
var_1 + var_2
# Out:
# 7

# %%
var_1 = 'Python'
var_1
# Out:
# 'Python'

# %% [markdown]
# > 변수의 자료형은 데이터형을 유추하여 자료형이 변경된다.

# %%
var_1 = 5
print(var_1)
print(var_2)
print(var_1 + var_2)
# Out:
# 5
# 5
# 10

# %% [markdown]
# ---
# # 조건문

# %%
var_1 = 4
var_2 = 3

if var_1 > var_2 :
    print('var_1 is greater than var_2')
# Out:
# var_1 is greater than var_2

# %% [markdown]
# ---
# # 반복문

# %%
for i in [10, 20, 30]:
    print(i)
# Out:
# 10
# 20
# 30

# %%
i = 0
while i < 30:
    # i = i + 10
    i += 10
    print(i)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ---
# ### 함수

# %%
def sumF(num1, num2):
    return num1 + num2

# %%
sumF(10, 20)
# Out:
# 30
