# %% [markdown]
# #### 예외처리

# %%
# Example

try:
    print(4/0)
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
try:
    print(4/0)
except Exception as e:
    print("시스템 점검 중입니다.")
    print(e)
# Out:
# 시스템 점검 중입니다.
# division by zero

# %%
# Example
try:
    f = open("../Data/text.txt", 'r')
    data = f.read()
    f.close
except Exception as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: '../Data/text.txt'

# %% [markdown]
# ---
# ### assert
# : Exception을 주어진 메세지로 발생 시킨다.

# %%
age = input(int("나이 입력 :"))
assert age >= 0, "나이가 마이너스입니다"
print(f"당신의 나이는 {age}세 입니다")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 age = input(int("나이 입력 :"))
#       2 assert age >= 0, "나이가 마이너스입니다"
#       3 print(f"당신의 나이는 {age}세 입니다")
#
# ValueError: invalid literal for int() with base 10: '나이 입력 :'
